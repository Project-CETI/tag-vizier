# %%
import requests

# %%
class SwarmAPI:
    def __init__(self):
        self.recent_data = {}
        self.msg_cached=False
        self.recent_telemetry = {}
        self.tel_cached=False
        self.authVal = self._login()
    
    def _login(self):
        url = "https://bumblebee.hive.swarm.space/hive/login"
        payload='username=ceti&password=1pE%5ELBAO8z%24kdg%239nTQ5WnMKXERrI%5EG%24M2POTuyy9A'
        headers = {'Content-Type': 'application/x-www-form-urlencoded',}
        response = requests.request("POST", url,
                                    headers=headers,
                                    data=payload)
        print("Login succeeded? %s" % str(response.status_code==200))
        return 'Bearer %s' % response.json()["token"]

    def _get_messages(self):
        url = "https://bumblebee.hive.swarm.space/hive/api/v1/messages?organizationId=65466&userApplicationId=65535&devicetype=1&deviceid=0x01d27&direction=fromdevice&count=1000"

        payload={}
        headers = {
          'accept': 'application/json',
          'Authorization': self.authVal
        }

        response = requests.request("GET", url,
                                    headers=headers,
                                    data=payload)

        if response.status_code == 200:
            self.recent_data = response.json()
            self.msg_cached = True
            return None
        print("Message GET failed.")

    def _get_telemetry(self):
        url = "https://bumblebee.hive.swarm.space/hive/api/v1/telemetry/devices?organizationId=65466&srcDeviceType=1&count=1000&sortAsc=false"

        payload={}
        headers = {
          'accept': 'application/json',
          'Authorization': self.authVal,
        }

        response = requests.request("GET", url,
                                    headers=headers,
                                    data=payload)
        if response.status_code == 200:
            self.recent_telemetry=response.json()
            self.tel_cached = True
            return None
        print("Telemetry GET failed.")

    def get_recent_data(self, use_cached=True):
        if not (use_cached and self.msg_cached and self.tel_cached):
            self._get_messages()
            self._get_telemetry()
            print("No cache?")
        return [self.recent_data,
                self.recent_telemetry]

    def logout(self):
        url = "https://bumblebee.hive.swarm.space/hive/logout"
        payload={}
        headers = {'Authorization': self.authVal}
        response=requests.request("GET",url,
                                       headers=headers,
                                       data=payload)
        print("Logout succeeded? %s" % str(response.status_code==204))

# %%
sapi=SwarmAPI()
# Out:
# Login succeeded? True

# %%
sapi.logout()
# Out:
# Logout succeeded? False

# %%
sapi.get_recent_data(False)
# Out:
# Message GET failed.
# Telemetry GET failed.
# No cache?
# [[{'packetId': 25573680,
#    'messageId': 25573680,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 137,
#    'data': 'eyJsbiI6LTYxLjM4OTEsInNpIjowLjAyNCwiYmkiOjAuMiwic3YiOjE0LjAsImx0IjoxNS4zMDEyLCJidiI6My44MTYsImQiOjE2NTM0NzIyNjYsIm4iOjQyNCwiYSI6My4wLCJzIjoxLjAsImMiOjExNC4wLCJyIjotOTQsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-25T15:35:11'},
#   {'packetId': 25560873,
#    'messageId': 25560873,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 136,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMCwiYmkiOjAuMiwic3YiOjAuMDI0LCJsdCI6MTUuMzAxMiwiYnYiOjMuODMyLCJkIjoxNjUzNDY4NjY2LCJuIjo0MjMsImEiOjIzLjAsInMiOjAuMCwiYyI6MTg2LjAsInIiOi05OSwidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-25T09:52:50'},
#   {'packetId': 25560872,
#    'messageId': 25560872,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 134,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMCwiYmkiOjAuMiwic3YiOjAuMDA4LCJsdCI6MTUuMzAxMywiYnYiOjMuODQ4LCJkIjoxNjUzNDY1MDY2LCJuIjo0MjIsImEiOjcuMCwicyI6MS4wLCJjIjoyNy4wLCJyIjotOTYsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-25T09:52:47'},
#   {'packetId': 25553617,
#    'messageId': 25553617,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId':
CJ0aSI6MC4wMzZ9',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-22T02:37:51'},
#   {'packetId': 25354096,
#    'messageId': 25354096,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 19736,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 138,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMCwiYmkiOjAuMjA4LCJzdiI6MC4wMDgsImx0IjoxNS4zMDEzLCJidiI6NC4wMzIsImQiOjE2NTMxNzY5OTYsIm4iOjM0MiwiYSI6MTUuMCwicyI6MS4wLCJjIjoxNjEuMCwiciI6LTk1LCJ0aSI6MC4wMzZ9',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-22T02:03:48'},
#   {'packetId': 25354091,
#    'messageId': 25354091,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 19736,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 137,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMDA0LCJiaSI6MC4yMDgsInN2IjozLjQ4LCJsdCI6MTUuMzAxMiwiYnYiOjQuMDQsImQiOjE2NTMxNzMzOTYsIm4iOjM0MSwiYSI6MTQuMCwicyI6MC4wLCJjIjo2MC4wLCJyIjotOTYsInRpIjowLjAzMn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-22T02:03:42'},
#   {'packetId': 25353555,
#    'messageId': 25353555,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 5412,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMDMyLCJiaSI6MC4yMDgsInN2IjoxOS4wMzIsImx0IjoxNS4zMDEzLCJidiI6NC4wNTYsImQiOjE2NTMxNjk3OTYsIm4iOjM0MCwiYSI6MjIuMCwicyI6MS4wLCJjIjo1NS4wLCJyIjotOTEsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-22T01:56:33'},
#   {'packetId': 25339569,
#    'messageId': 25339569,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 258774,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTEyLCJiaSI6MC4zMDQsInN2IjoyMC4zMjgsImx0IjoxNS4zMDEyLCJidiI6NC4xMiwiZCI6MTY1MzE2NjE5NiwibiI6MzM5LCJhIjoxNi4wLCJzIjoxLjAsImMiOjIzMi4wLCJyIjotOTQsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T21:00:21'},
#   {'packetId': 25339270,
#    'messageId': 25339270,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 258774,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 139,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTIsImJpIjowLjIxNiwic3YiOjIwLjE5MiwibHQiOjE1LjMwMTMsImJ2Ijo0LjEyLCJkIjoxNjUzMTYyNTkxLCJuIjozMzgsImEiOjE3LjAsInMiOjEuMCwiYyI6MTk2LjAsInIiOi04MywidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T20:55:08'},
#   {'packetId': 25339268,
#    'messageId': 25339268,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 258774,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTM2LCJiaSI6MC4yMTYsInN2IjoyMC4xMzYsImx0IjoxNS4zMDEzLCJidiI6NC4xMiwiZCI6MTY1MzE1ODk5MSwibiI6MzM3LCJhIjozMC4wLCJzIjoxLjAsImMiOjIwMC4wLCJyIjotNzIsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T20:55:05'},
#   {'packetId': 25339266,
#    'messageId': 25339266,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 258774,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTUyLCJiaSI6MC4yMTYsInN2IjoxOS43OTIsImx0IjoxNS4zMDEzLCJidiI6NC4xMiwiZCI6MTY1MzE1NTM5MSwibiI6MzM2LCJhIjoyMS4wLCJzIjoxLjAsImMiOjI2OS4wLCJyIjotNzEsInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T20:55:02'},
#   {'packetId': 25339262,
#    'messageId': 25339262,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 258774,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTcyLCJiaSI6MC4yMTYsInN2IjoxOS44MzIsImx0IjoxNS4zMDEyLCJidiI6NC4xMiwiZCI6MTY1MzE1MTc5MSwibiI6MzM1LCJhIjoyMi4wLCJzIjoxLjAsImMiOjEzOS4wLCJyIjotNjksInRpIjowLjAzNn0=',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T20:55:00'},
#   {'packetId': 25326526,
#    'messageId': 25326526,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 139,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMTk2LCJiaSI6MC4yMiwic3YiOjE3LjgzMiwibHQiOjE1LjMwMTIsImJ2Ijo0LjA4OCwiZCI6MTY1MzE0ODE5MSwibiI6MzM0LCJhIjo0LjAsInMiOjEuMCwiYyI6MjU1LjAsInIiOi03MCwidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T16:23:24'},
#   {'packetId': 25326522,
#    'messageId': 25326522,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 139,
#    'data': 'eyJsbiI6LTYxLjM4ODksInNpIjowLjMsImJpIjowLjIxNiwic3YiOjE2Ljg4OCwibHQiOjE1LjMwMTMsImJ2Ijo0LjA2NCwiZCI6MTY1MzE0NDU5MSwibiI6MzMzLCJhIjo5LjAsInMiOjEuMCwiYyI6MTAxLjAsInIiOi03MiwidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T16:23:21'},
#   {'packetId': 25326288,
#    'messageId': 25326288,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 139,
#    'data': 'eyJsbiI6LTYxLjM4OTEsInNpIjowLjE3NiwiYmkiOjAuMjA4LCJzdiI6MTYuNzYsImx0IjoxNS4zMDEzLCJidiI6My45MTIsImQiOjE2NTMxNDA5ODYsIm4iOjMzMiwiYSI6OS4wLCJzIjoxLjAsImMiOjUyLjAsInIiOi03OCwidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T16:20:34'},
#   {'packetId': 25326285,
#    'messageId': 25326285,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 139,
#    'data': 'eyJsbiI6LTYxLjM4OSwic2kiOjAuMDcyLCJiaSI6MC4yMDgsInN2IjoxNi42OCwibHQiOjE1LjMwMTIsImJ2IjozLjgzMiwiZCI6MTY1MzEzNzM4NiwibiI6MzMxLCJhIjo5LjAsInMiOjEuMCwiYyI6MTEyLjAsInIiOi04NCwidGkiOjAuMDM2fQ==',
#    'ackPacketId': 0,
#    'status': 0,
#    'hiveRxTime': '2022-05-21T16:20:31'},
#   {'packetId': 25326283,
#    'messageId': 25326283,
#    'deviceType': 1,
#    'deviceId': 7463,
#    'direction': 1,
#    'viaDeviceId': 43066,
#    'dataType': 6,
#    'userApplicationId': 65535,
#    'organizationId': 65466,
#    'len': 140,
# ...
#    'telemetryCourse': 91,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 30414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21339835,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-18T06:18:13',
#    'telemetryLatitude': 42.65392303466797,
#    'telemetryLongitude': -71.16199493408203,
#    'telemetryAltitude': 154,
#    'telemetryCourse': 275,
#    'telemetrySpeed': 400,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21338066,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-18T05:24:26',
#    'telemetryLatitude': 42.65398406982422,
#    'telemetryLongitude': -71.16278076171875,
#    'telemetryAltitude': 38,
#    'telemetryCourse': 17,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21338065,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-18T05:24:26',
#    'telemetryLatitude': 42.65398406982422,
#    'telemetryLongitude': -71.16278076171875,
#    'telemetryAltitude': 38,
#    'telemetryCourse': 17,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21337701,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-18T05:13:27',
#    'telemetryLatitude': 42.65412902832031,
#    'telemetryLongitude': -71.16275787353516,
#    'telemetryAltitude': 35,
#    'telemetryCourse': 80,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29514,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21320196,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T21:58:28',
#    'telemetryLatitude': 42.65412521362305,
#    'telemetryLongitude': -71.16288757324219,
#    'telemetryAltitude': 45,
#    'telemetryCourse': 244,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21315890,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T20:07:01',
#    'telemetryLatitude': 42.65394973754883,
#    'telemetryLongitude': -71.16294860839844,
#    'telemetryAltitude': 51,
#    'telemetryCourse': 330,
#    'telemetrySpeed': 0,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21314225,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T19:14:14',
#    'telemetryLatitude': 42.65401840209961,
#    'telemetryLongitude': -71.16307067871094,
#    'telemetryAltitude': 5,
#    'telemetryCourse': 309,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29914,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21312693,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T18:34:21',
#    'telemetryLatitude': 42.65409851074219,
#    'telemetryLongitude': -71.16266632080078,
#    'telemetryAltitude': 51,
#    'telemetryCourse': 193,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 30214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21300073,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T14:08:45',
#    'telemetryLatitude': 42.65425109863281,
#    'telemetryLongitude': -71.16285705566406,
#    'telemetryAltitude': -88,
#    'telemetryCourse': 315,
#    'telemetrySpeed': 300,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29714,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21300090,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T14:08:45',
#    'telemetryLatitude': 42.65425109863281,
#    'telemetryLongitude': -71.16285705566406,
#    'telemetryAltitude': -88,
#    'telemetryCourse': 315,
#    'telemetrySpeed': 300,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29714,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21300043,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T14:07:49',
#    'telemetryLatitude': 42.653316497802734,
#    'telemetryLongitude': -71.16060638427734,
#    'telemetryAltitude': -140,
#    'telemetryCourse': 123,
#    'telemetrySpeed': 9700,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29714,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21300042,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T14:07:49',
#    'telemetryLatitude': 42.653316497802734,
#    'telemetryLongitude': -71.16060638427734,
#    'telemetryAltitude': -140,
#    'telemetryCourse': 123,
#    'telemetrySpeed': 9700,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29714,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21286229,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T07:10:56',
#    'telemetryLatitude': 42.65401077270508,
#    'telemetryLongitude': -71.16263580322266,
#    'telemetryAltitude': 55,
#    'telemetryCourse': 262,
#    'telemetrySpeed': 0,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21284560,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T06:09:01',
#    'telemetryLatitude': 42.65396499633789,
#    'telemetryLongitude': -71.1628646850586,
#    'telemetryAltitude': 73,
#    'telemetryCourse': 231,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21284561,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T06:09:01',
#    'telemetryLatitude': 42.65396499633789,
#    'telemetryLongitude': -71.1628646850586,
#    'telemetryAltitude': 73,
#    'telemetryCourse': 231,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21283618,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T05:36:47',
#    'telemetryLatitude': 42.65386199951172,
#    'telemetryLongitude': -71.16252136230469,
#    'telemetryAltitude': 81,
#    'telemetryCourse': 165,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21283617,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-17T05:36:47',
#    'telemetryLatitude': 42.65386199951172,
#    'telemetryLongitude': -71.16252136230469,
#    'telemetryAltitude': 81,
#    'telemetryCourse': 165,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21259631,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T19:25:37',
#    'telemetryLatitude': 42.654075622558594,
#    'telemetryLongitude': -71.16203308105469,
#    'telemetryAltitude': 160,
#    'telemetryCourse': 59,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21257525,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T18:30:31',
#    'telemetryLatitude': 42.654232025146484,
#    'telemetryLongitude': -71.16258239746094,
#    'telemetryAltitude': 47,
#    'telemetryCourse': 30,
#    'telemetrySpeed': 400,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 30214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21257524,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T18:30:31',
#    'telemetryLatitude': 42.654232025146484,
#    'telemetryLongitude': -71.16258239746094,
#    'telemetryAltitude': 47,
#    'telemetryCourse': 30,
#    'telemetrySpeed': 400,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 30214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21246076,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T14:26:45',
#    'telemetryLatitude': 42.65411376953125,
#    'telemetryLongitude': -71.16271209716797,
#    'telemetryAltitude': 38,
#    'telemetryCourse': 266,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 30314,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21237781,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T09:57:37',
#    'telemetryLatitude': 42.65410614013672,
#    'telemetryLongitude': -71.162841796875,
#    'telemetryAltitude': 36,
#    'telemetryCourse': 89,
#    'telemetrySpeed': 400,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28914,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21230799,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T06:20:02',
#    'telemetryLatitude': 42.654109954833984,
#    'telemetryLongitude': -71.16297912597656,
#    'telemetryAltitude': 29,
#    'telemetryCourse': 269,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28814,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21228567,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T05:12:15',
#    'telemetryLatitude': 42.65425491333008,
#    'telemetryLongitude': -71.1625747680664,
#    'telemetryAltitude': 44,
#    'telemetryCourse': 13,
#    'telemetrySpeed': 600,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21228551,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T05:12:15',
#    'telemetryLatitude': 42.65425491333008,
#    'telemetryLongitude': -71.1625747680664,
#    'telemetryAltitude': 44,
#    'telemetryCourse': 13,
#    'telemetrySpeed': 600,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21227993,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-16T04:55:50',
#    'telemetryLatitude': 42.65386962890625,
#    'telemetryLongitude': -71.1624984741211,
#    'telemetryAltitude': 103,
#    'telemetryCourse': 221,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29314,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21139479,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-14T06:43:00',
#    'telemetryLatitude': 42.65395736694336,
#    'telemetryLongitude': -71.1624755859375,
#    'telemetryAltitude': 65,
#    'telemetryCourse': 114,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28114,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21138816,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-14T06:11:58',
#    'telemetryLatitude': 42.654014587402344,
#    'telemetryLongitude': -71.16283416748047,
#    'telemetryAltitude': 46,
#    'telemetryCourse': 305,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21138700,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-14T06:08:38',
#    'telemetryLatitude': 42.65418243408203,
#    'telemetryLongitude': -71.16284942626953,
#    'telemetryAltitude': 52,
#    'telemetryCourse': 305,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28714,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21117921,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T18:37:25',
#    'telemetryLatitude': 42.65412139892578,
#    'telemetryLongitude': -71.1626968383789,
#    'telemetryAltitude': 51,
#    'telemetryCourse': 79,
#    'telemetrySpeed': 0,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29214,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21117577,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T18:27:31',
#    'telemetryLatitude': 42.654232025146484,
#    'telemetryLongitude': -71.16294860839844,
#    'telemetryAltitude': 33,
#    'telemetryCourse': 110,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29414,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21098052,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T06:16:53',
#    'telemetryLatitude': 42.65398406982422,
#    'telemetryLongitude': -71.16253662109375,
#    'telemetryAltitude': 53,
#    'telemetryCourse': 103,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28614,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21098051,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T06:16:53',
#    'telemetryLatitude': 42.65398406982422,
#    'telemetryLongitude': -71.16253662109375,
#    'telemetryAltitude': 53,
#    'telemetryCourse': 103,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 33,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28614,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21098026,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T06:16:22',
#    'telemetryLatitude': 42.65406036376953,
#    'telemetryLongitude': -71.16283416748047,
#    'telemetryAltitude': 38,
#    'telemetryCourse': 106,
#    'telemetrySpeed': 300,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28514,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 21097483,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-13T05:46:56',
#    'telemetryLatitude': 42.65403747558594,
#    'telemetryLongitude': -71.16284942626953,
#    'telemetryAltitude': 55,
#    'telemetryCourse': 264,
#    'telemetrySpeed': 200,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 28614,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 20889054,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-08T07:21:36',
#    'telemetryLatitude': 42.65415954589844,
#    'telemetryLongitude': -71.16277313232422,
#    'telemetryAltitude': 49,
#    'telemetryCourse': 325,
#    'telemetrySpeed': 0,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29014,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 20887231,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-08T06:04:07',
#    'telemetryLatitude': 42.65406799316406,
#    'telemetryLongitude': -71.16285705566406,
#    'telemetryAltitude': 27,
#    'telemetryCourse': 47,
#    'telemetrySpeed': 0,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29014,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 20886965,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-08T05:51:39',
#    'telemetryLatitude': 42.65397644042969,
#    'telemetryLongitude': -71.16287231445312,
#    'telemetryAltitude': 71,
#    'telemetryCourse': 155,
#    'telemetrySpeed': 100,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29314,
#    'deviceType': 1,
#    'deviceId': 7463},
#   {'packetId': 20886827,
#    'telemetryVersion': 1,
#    'telemetryAt': '2022-03-08T05:49:07',
#    'telemetryLatitude': 42.65275955200195,
#    'telemetryLongitude': -71.16728973388672,
#    'telemetryAltitude': 59,
#    'telemetryCourse': 251,
#    'telemetrySpeed': 19800,
#    'telemetryBatteryVoltage': 34,
#    'telemetryBatteryCurrent': 0,
#    'telemetryTemperatureK': 29314,
#    'deviceType': 1,
#    'deviceId': 7463}]]

# %%
# backup logout
requests.request("GET",
                 "https://bumblebee.hive.swarm.space/hive/logout",
                 headers={"Authorization": sapi.authVal},
                 data={},)
# Out:
# <Response [204]>

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
mysql
# Out:
# <module 'mysql' from '/home/shashank/.local/lib/python3.10/site-packages/mysql/__init__.py'>

# %%
cnx = mysql.connector.connect(user='root',
                              password='m0d0c3@|\|0502',
                              host='127.0.0.1',
                              database='test')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:246, in CMySQLConnection._open_connection(self)
#     245 try:
# --> 246     self._cmysql.connect(**cnx_kwargs)
#     247     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 cnx = mysql.connector.connect(user='root',password='m0d0c3@|\|0502',host='127.0.0.1',database='test')
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/__init__.py:272, in connect(*args, **kwargs)
#     269         raise ImportError(ERROR_NO_CEXT)
#     271 if HAVE_CEXT and not use_pure:
# --> 272     return CMySQLConnection(*args, **kwargs)
#     273 return MySQLConnection(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:94, in CMySQLConnection.__init__(self, **kwargs)
#      91 super(CMySQLConnection, self).__init__(**kwargs)
#      93 if kwargs:
# ---> 94     self.connect(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/abstracts.py:1052, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1049     self.config(**kwargs)
#    1051 self.disconnect()
# -> 1052 self._open_connection()
#    1053 # Server does not allow to run any other statement different from ALTER
#    1054 # when user's password has been expired.
#    1055 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File ~/.local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:251, in CMySQLConnection._open_connection(self)
#     249         self.converter.str_fallback = self._converter_str_fallback
#     250 except MySQLInterfaceError as exc:
# --> 251     raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#     252                                      sqlstate=exc.sqlstate)
#     254 self._do_handshake()
#
# ProgrammingError: 1698 (28000): Access denied for user 'root'@'localhost'
